# %% [markdown]
# # Lesson 1: Data Loading

# %% [markdown]
# ## Introduction
#
# Data Loading is the first step in any data analysis or data science project.
# In this lesson, we will learn how to load data using pandas and explore it briefly.

# %% [markdown]
# ## Import Library

# %%
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#    id    name   age department  salary
# 0   1     Ali  25.0         IT     800
# 1   2    Sara  30.0         HR     700
# 2   3  Hassan  28.0    Finance     750
# 3   4  Zainab  35.0         IT     900
# 4   5    Omar   NaN         HR     650

# %% [markdown]
# ## Explain Loading

# %% [markdown]
# The `read_csv()` function is used to load data from a CSV file into a DataFrame.
# The `head()` function shows the first five rows of the dataset.

# %% [markdown]
# ## Simple Data Cleaning

# %%
df.isnull().sum()
# Out:
# id            0
# name          0
# age           1
# department    0
# salary        0
# dtype: int64

# %% [markdown]
# ## Explain Cleaning

# %% [markdown]
# This step helps us detect missing values in the dataset.
# Missing values are common in real-world data and must be handled later.

# %% [markdown]
# ## Columns Information

# %%
df.columns
# Out:
# Index(['id', 'name', 'age', 'department', 'salary'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          5 non-null      int64
#  1   name        5 non-null      object
#  2   age         4 non-null      float64
#  3   department  5 non-null      object
#  4   salary      5 non-null      int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 332.0+ bytes

# %% [markdown]
# The `info()` function provides a summary of the dataset including data types and memory usage.

# %% [markdown]
# ## Explain Columns

# %% [markdown]
# Each column represents a specific feature:
# - id: Employee ID
# - name: Employee name
# - age: Employee age
# - department: Work department
# - salary: Monthly salary

# %% [markdown]
# ## Questions for Students

# %% [markdown]
# ## Questions
#
# 1. What is the purpose of the `read_csv()` function?
# 2. Why do we use the `head()` function after loading data?
# 3. What does missing data mean?

# %% [markdown]
# ## Simple Exercise

# %% [markdown]
# ## Exercise
#
# 1. Load the CSV file.
# 2. Display the first 5 rows.
# 3. Print the column names.
# 4. Show the number of rows and columns.

# %% [markdown]
# ## Exercise Code Template

# %%
# Write your solution here
